# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import make_union
from sklearn.compose import make_column_transformer
from imblearn.over_sampling import SMOTE, SMOTENC
pd.set_option('display.max_columns', None)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score

# %%
data = pd.read_csv("dataset.csv", sep=";", error_bad_lines=False)
# Out:
# /var/folders/1f/zhjqphp10m9f4rqq73knjdyr0000gn/T/ipykernel_35838/1124257443.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv("dataset.csv", sep=";", error_bad_lines=False)

# %%
data.shape
# Out:
# (99976, 43)

# %%
df = data.dropna()

# %%
df.shape
# Out:
#                                     uuid  default  \
# 7   575cebe3-2807-4dcb-8047-cf4ca9476a4d      0.0
# 8   320f1544-064f-4568-a5f0-4ed54e91483a      0.0
# 47  adc8c99d-2d3f-401a-8b8f-24d43f34ee70      0.0
# 50  919175d3-b520-4b45-99bc-4b63952ad559      0.0
# 53  22861eed-aea4-4b15-83a7-71f1609ca1af      0.0
#
#     account_amount_added_12_24m  account_days_in_dc_12_24m  \
# 7                         57229                        0.0
# 8                        148922                        0.0
# 47                         6383                        0.0
# 50                       116160                        0.0
# 53                        49124                        0.0
#
#     account_days_in_rem_12_24m  account_days_in_term_12_24m  \
# 7                          0.0                          0.0
# 8                         47.0                          0.0
# 47                         0.0                          0.0
# 50                        26.0                          0.0
# 53                        24.0                          0.0
#
#     account_incoming_debt_vs_paid_0_24m  account_status  \
# 7                              0.232244             1.0
# 8                              0.969055             1.0
# 47                             0.000000             1.0
# 50                             0.167464             1.0
# 53                             0.450548             1.0
#
#     account_worst_status_0_3m  account_worst_status_12_24m  ...  \
# 7                         1.0                          1.0  ...
# 8                         2.0                          2.0  ...
# 47                        1.0                          1.0  ...
# 50                        1.0                          2.0  ...
# 53                        1.0                          2.0  ...
#
#     status_3rd_last_archived_0_24m  status_max_archived_0_6_months  \
# 7                                1                               1
# 8                                2                               2
# 47                               1                               2
# 50                               1                               1
# 53                               1                               1
#
#     status_max_archived_0_12_months  status_max_archived_0_24_months  \
# 7                                 1                                1
# 8                                 2                                2
# 47                                2                                2
# 50                                1                                1
# 53                                1                                2
#
#     recovery_debt sum_capital_paid_account_0_12m  \
# 7               0                          42206
# 8               0                         104643
# 47              0                              0
# 50              0                              0
# 53              0                          37725
#
#    sum_capital_paid_account_12_24m  sum_paid_inv_0_12m  time_hours  \
# 7                            35336              457257   12.192778
# 8                            32381               24390   21.411111
# 47                            3190              123306   21.699167
# 50                               0               86972    7.137500
# 53                           48560              116748   20.971667
#
#     worst_status_active_inv
# 7                       1.0
# 8                       1.0
# 47                      2.0
# 50                      1.0
# 53                      1.0
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Defining data to predict

# %%
pred_df = data[data["default"].isna()]

# %%
pred_df.shape
# Out:
# (10000, 43)

# %% [markdown]
# ### Cleaning data

# %%
df["default"].value_counts()
# Out:
# 0.0    9020
# 1.0      91
# Name: default, dtype: int64

# %%
(df==0).sum().sort_values(ascending=False)/len(df)
# Out:
# num_arch_written_off_12_24m            1.000000
# num_arch_written_off_0_12m             0.999671
# account_days_in_dc_12_24m              0.995610
# recovery_debt                          0.993524
# default                                0.990012
# account_days_in_term_12_24m            0.971683
# num_arch_dc_0_12m                      0.909340
# num_arch_dc_12_24m                     0.907914
# account_days_in_rem_12_24m             0.717265
# num_arch_rem_0_12m                     0.485457
# account_incoming_debt_vs_paid_0_24m    0.286467
# sum_capital_paid_account_12_24m        0.185380
# sum_capital_paid_account_0_12m         0.180880
# account_amount_added_12_24m            0.081111
# num_arch_ok_12_24m                     0.073318
# status_3rd_last_archived_0_24m         0.026122
# num_arch_ok_0_12m                      0.018549
# status_max_archived_0_6_months         0.015805
# avg_payment_span_0_3m                  0.010317
# status_2nd_last_archived_0_24m         0.009439
# status_max_archived_0_12_months        0.004829
# max_paid_inv_0_12m                     0.002963
# sum_paid_inv_0_12m                     0.002963
# avg_payment_span_0_12m                 0.001866
# max_paid_inv_0_24m                     0.000549
# status_last_archived_0_24m             0.000549
# status_max_archived_0_24_months        0.000549
# num_unpaid_bills                       0.000000
# time_hours                             0.000000
# uuid                                   0.000000
# num_active_div_by_paid_inv_0_12m       0.000000
# num_active_inv                         0.000000
# name_in_email                          0.000000
# has_paid                               0.000000
# merchant_group                         0.000000
# merchant_category                      0.000000
# age                                    0.000000
# account_worst_status_6_12m             0.000000
# account_worst_status_3_6m              0.000000
# account_worst_status_12_24m            0.000000
# account_worst_status_0_3m              0.000000
# account_status                         0.000000
# worst_status_active_inv                0.000000
# dtype: float64

# %%
X = df.drop(columns=["default", "num_arch_written_off_12_24m", "num_arch_written_off_0_12m",
                     "account_days_in_dc_12_24m", "recovery_debt", "account_days_in_term_12_24m",
                     "num_arch_dc_0_12m", "num_arch_dc_12_24m", "account_days_in_rem_12_24m",
                     "num_arch_rem_0_12m"])
y = df["default"]

# %%
new_data.columns
# Out:
# Index(['uuid', 'default', 'account_amount_added_12_24m',
#        'account_days_in_dc_12_24m', 'account_days_in_rem_12_24m',
#        'account_days_in_term_12_24m', 'account_incoming_debt_vs_paid_0_24m',
#        'account_status', 'account_worst_status_0_3m',
#        'account_worst_status_12_24m', 'account_worst_status_3_6m',
#        'account_worst_status_6_12m', 'age', 'avg_payment_span_0_12m',
#        'avg_payment_span_0_3m', 'merchant_category', 'merchant_group',
#        'has_paid', 'max_paid_inv_0_12m', 'max_paid_inv_0_24m', 'name_in_email',
#        'num_active_div_by_paid_inv_0_12m', 'num_active_inv',
#        'num_arch_dc_0_12m', 'num_arch_dc_12_24m', 'num_arch_ok_0_12m',
#        'num_arch_ok_12_24m', 'num_arch_rem_0_12m',
#        'num_arch_written_off_0_12m', 'num_arch_written_off_12_24m',
#        'num_unpaid_bills', 'status_last_archived_0_24m',
#        'status_2nd_last_archived_0_24m', 'status_3rd_last_archived_0_24m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_12_months',
#        'status_max_archived_0_24_months', 'recovery_debt',
#        'sum_capital_paid_account_0_12m', 'sum_capital_paid_account_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours', 'worst_status_active_inv'],
#       dtype='object')

# %% [markdown]
# ### split X and y

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
y_train.value_counts()
# Out:
# 0.0    7220
# 1.0      68
# Name: default, dtype: int64

# %%
X.drop(columns="name_in_email", inplace=True)

# %%
X.drop(columns="uuid", inplace=True)

# %%
X.head()
# Out:
#     account_amount_added_12_24m  account_incoming_debt_vs_paid_0_24m  \
# 7                         57229                             0.232244
# 8                        148922                             0.969055
# 47                         6383                             0.000000
# 50                       116160                             0.167464
# 53                        49124                             0.450548
#
#     account_status  account_worst_status_0_3m  account_worst_status_12_24m  \
# 7              1.0                        1.0                          1.0
# 8              1.0                        2.0                          2.0
# 47             1.0                        1.0                          1.0
# 50             1.0                        1.0                          2.0
# 53             1.0                        1.0                          2.0
#
#     account_worst_status_3_6m  account_worst_status_6_12m  age  \
# 7                         1.0                         1.0   34
# 8                         2.0                         2.0   40
# 47                        1.0                         1.0   41
# 50                        1.0                         1.0   21
# 53                        1.0                         1.0   42
#
#     avg_payment_span_0_12m  avg_payment_span_0_3m          merchant_category  \
# 7                26.930233              25.866667  Diversified entertainment
# 8                33.727273              37.571429  Diversified entertainment
# 47               14.250000              13.000000  Diversified entertainment
# 50               20.428571              21.500000  Youthful Shoes & Clothing
# 53               18.708333              18.000000        Dietary supplements
#
#       merchant_group  has_paid  max_paid_inv_0_12m  max_paid_inv_0_24m  \
# 7      Entertainment      True              8655.0              9645.0
# 8      Entertainment      True              6075.0              9090.0
# 47     Entertainment      True             18385.0             18385.0
# 50  Clothing & Shoes      True             16790.0             22570.0
# 53   Health & Beauty      True             16237.0             18608.0
#
#     num_active_div_by_paid_inv_0_12m  num_active_inv  num_arch_ok_0_12m  \
# 7                           0.083333              20                215
# 8                           0.818182               9                  3
# 47                          0.225000               9                 33
# 50                          0.285714               2                  7
# 53                          0.080000               2                 24
#
#     num_arch_ok_12_24m  num_unpaid_bills  status_last_archived_0_24m  \
# 7                  257                37                           1
# 8                    2                23                           1
# 47                  45                 9                           1
# 50                  11                 2                           1
# 53                  25                16                           1
#
#     status_2nd_last_archived_0_24m  status_3rd_last_archived_0_24m  \
# 7                                1                               1
# 8                                2                               2
# 47                               1                               1
# 50                               1                               1
# 53                               1                               1
#
#     status_max_archived_0_6_months  status_max_archived_0_12_months  \
# 7                                1                                1
# 8                                2                                2
# 47                               2                                2
# 50                               1                                1
# 53                               1                                1
#
#     status_max_archived_0_24_months  sum_capital_paid_account_0_12m  \
# 7                                 1                           42206
# 8                                 2                          104643
# 47                                2                               0
# 50                                1                               0
# 53                                2                           37725
#
#     sum_capital_paid_account_12_24m  sum_paid_inv_0_12m  time_hours  \
# 7                             35336              457257   12.192778
# 8                             32381               24390   21.411111
# 47                             3190              123306   21.699167
# 50                                0               86972    7.137500
# 53                            48560              116748   20.971667
#
#     worst_status_active_inv
# 7                       1.0
# 8                       1.0
# 47                      2.0
# 50                      1.0
# 53                      1.0

# %%
# Out:
# 0.0    7221
# 1.0      67
# Name: default, dtype: int64

# %% [markdown]
# ### splitting num and cat features

# %%
num_features = X_train.select_dtypes(include="number")
cat_features = X_train.select_dtypes(exclude="number")

# %%
X_train.columns
# Out:
# Index(['account_amount_added_12_24m', 'account_incoming_debt_vs_paid_0_24m',
#        'account_status', 'account_worst_status_0_3m',
#        'account_worst_status_12_24m', 'account_worst_status_3_6m',
#        'account_worst_status_6_12m', 'age', 'avg_payment_span_0_12m',
#        'avg_payment_span_0_3m', 'merchant_category', 'merchant_group',
#        'has_paid', 'max_paid_inv_0_12m', 'max_paid_inv_0_24m',
#        'num_active_div_by_paid_inv_0_12m', 'num_active_inv',
#        'num_arch_ok_0_12m', 'num_arch_ok_12_24m', 'num_unpaid_bills',
#        'status_last_archived_0_24m', 'status_2nd_last_archived_0_24m',
#        'status_3rd_last_archived_0_24m', 'status_max_archived_0_6_months',
#        'status_max_archived_0_12_months', 'status_max_archived_0_24_months',
#        'sum_capital_paid_account_0_12m', 'sum_capital_paid_account_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours', 'worst_status_active_inv'],
#       dtype='object')

# %%
y_train.shape
# Out:
# (7288,)

# %% [markdown]
# ### Pre-processing pipelines

# %%
from sklearn import set_config; set_config(display='diagram')

# %%
num_transformer = make_pipeline(RobustScaler())
cat_transformer = make_pipeline(OneHotEncoder())

preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, num_features),
    ('cat_transformer', cat_transformer, cat_features)
])
pipeline = make_pipeline(preprocessor, LogisticRegression())
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_transformer',
#                                                   Pipeline(steps=[('robustscaler',
#                                                                    RobustScaler())]),
#                                                   Index(['account_amount_added_12_24m', 'account_incoming_debt_vs_paid_0_24m',
#        'account_status', 'account_worst_status_0_3m',
#        'account_worst_status_12_24m', 'account_worst_status_3_6m',
#        'account_worst_status_6_12m', 'age'...
#        'status_max_archived_0_12_months', 'status_max_archived_0_24_months',
#        'sum_capital_paid_account_0_12m', 'sum_capital_paid_account_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours', 'worst_status_active_inv'],
#       dtype='object')),
#                                                  ('cat_transformer',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   Index(['merchant_category', 'merchant_group', 'has_paid'], dtype='object'))])),
#                 ('logisticregression', LogisticRegression())])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_transformer',
#                                                   Pipeline(steps=[('robustscaler',
#                                                                    RobustScaler())]),
#                                                   Index(['account_amount_added_12_24m', 'account_incoming_debt_vs_paid_0_24m',
#        'account_status', 'account_worst_status_0_3m',
#        'account_worst_status_12_24m', 'account_worst_status_3_6m',
#        'account_worst_status_6_12m', 'age'...
#        'status_max_archived_0_12_months', 'status_max_archived_0_24_months',
#        'sum_capital_paid_account_0_12m', 'sum_capital_paid_account_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours', 'worst_status_active_inv'],
#       dtype='object')),
#                                                  ('cat_transformer',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   Index(['merchant_category', 'merchant_group', 'has_paid'], dtype='object'))])),
#                 ('logisticregression', LogisticRegression())])

# %%
y_test.shape
# Out:
# (1823,)

# %%
train_auc = roc_auc_score(y_train, pipeline.predict_proba(X_train)[:, 1])
test_auc = roc_auc_score(y_test, pipeline.predict_proba(X_test)[:, 1])

print(f"Train AUC: {train_auc}")
print(f"Test AUC: {test_auc}")
# Out:
# Train AUC: 0.9477394911607314
# Test AUC: 0.933319436724106

# %%
mask_na = data.default.isna()
new_data = data[mask_na]

# %%
X_train.columns
# Out:
# Index(['account_amount_added_12_24m', 'account_incoming_debt_vs_paid_0_24m',
#        'account_status', 'account_worst_status_0_3m',
#        'account_worst_status_12_24m', 'account_worst_status_3_6m',
#        'account_worst_status_6_12m', 'age', 'avg_payment_span_0_12m',
#        'avg_payment_span_0_3m', 'merchant_category', 'merchant_group',
#        'has_paid', 'max_paid_inv_0_12m', 'max_paid_inv_0_24m',
#        'num_active_div_by_paid_inv_0_12m', 'num_active_inv',
#        'num_arch_ok_0_12m', 'num_arch_ok_12_24m', 'num_unpaid_bills',
#        'status_last_archived_0_24m', 'status_2nd_last_archived_0_24m',
#        'status_3rd_last_archived_0_24m', 'status_max_archived_0_6_months',
#        'status_max_archived_0_12_months', 'status_max_archived_0_24_months',
#        'sum_capital_paid_account_0_12m', 'sum_capital_paid_account_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours', 'worst_status_active_inv'],
#       dtype='object')

# %%
new_data = new_data.drop(columns=["default", "num_arch_written_off_12_24m", "num_arch_written_off_0_12m",
                     "account_days_in_dc_12_24m", "recovery_debt", "account_days_in_term_12_24m",
                     "num_arch_dc_0_12m", "num_arch_dc_12_24m", "account_days_in_rem_12_24m",
                     "num_arch_rem_0_12m", "uuid", "name_in_email"])
